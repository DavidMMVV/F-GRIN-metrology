# %%
import numpy as np
import matplotlib.pyplot as plt

def FT(x):
    return np.fft.fftshift(np.fft.fft(np.fft.ifftshift(x)))

def iFT(x):
    return np.fft.fftshift(np.fft.fft(np.fft.ifftshift(x)))

# %% [markdown]
# ## Gradient computation of the propagated field
#
# For PCA, SGD, and all the analysis over the functional $\mathca{L}^2$ with respect to $n$ requires to determine the semianalytical expression of the gradient (expressed as the composition of different operators). The

# %% [markdown]
# $\mathcal{e}^{\pi i} - 1 < 0$

# %% [markdown]
# Imagine I have a confined gaussian beam comming from

# %%
import jax.numpy as jnp
import matplotlib.pyplot as plt

Nz, Ny, Nx = (100, 100, 100)
wavelength = 1
sdv = 10

dq_x_0 = jnp.linspace(0, 1 / wavelength, 100)
dq_y_0 = jnp.linspace(0, 1 / wavelength, 100)
dq_r_0 = jnp.linspace(0, 100)
dz = jnp.sqrt((1 / wavelength**2) - dq_x_0**2 - dq_y_0**2)

# I take measurements in 4 real detectors
x = jnp.linspace(1, 100, 100)
y = jnp.linspace(1, 100, 100)

gaussian_beam = jnp.exp()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 17
#      14 x = jnp.linspace(1, 100, 100)
#      15 y = jnp.linspace(1, 100, 100)
# ---> 17 gaussian_beam = jnp.exp()
#
#     [... skipping hidden 12 frame]
#
# File ~/miniconda3/envs/f-grin-metrology/lib/python3.13/site-packages/jax/_src/linear_util.py:429, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     427 @transformation_with_aux2
#     428 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 429   ans = _fun(*args, **kwargs)
#     430   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     431   if _store:
#     432     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     433     # the bwd function in a custom_vjp
#
# TypeError: exp() missing 1 required positional argument: 'x'

# %% [markdown]
# X =

# %%
x_0 = 0
y_0 = 0
z_0 = 0


aperture = 100 * wavelength
sigma = aperture **2 / (wavelength * focus)

psf = jnp.exp(((x-x_0)**2 + (y-y_0)**2) / sigma**2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 z_0 = 0
#       6 aperture = 100 * wavelength
# ----> 7 sigma = aperture **2 / (wavelength * focus)
#       9 psf = jnp.exp(((x-x_0)**2 + (y-y_0)**2) / sigma**2)
#
# NameError: name 'focus' is not defined

# %%
#ai_approach
# We first define our space
